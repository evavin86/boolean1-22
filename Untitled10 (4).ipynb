# %% [markdown]
# 1 Boolean

# %%
A = int(input())
result = A > 0
print(result)
# Out:
# Введите целое число A: 2
# True

# %% [markdown]
# 2 boolean

# %%
A = int(input())
result = A % 2 != 0
print(result)
# Out:
# Введите целое число A: 3
# True

# %% [markdown]
# 3

# %%
A = int(input())
result = A % 2 == 0
print(result)
# Out:
# Введите целое число A: 5
# False

# %% [markdown]
# 4

# %%
A = int(input())
B = int(input())
result = (A > 2) and (B <= 3)
print(result)
# Out:
# 6
# 3
# True

# %% [markdown]
# 5

# %%
A = int(input())
B = int(input())
result = (A >= 0) and (B < -2)
print(result)
# Out:
# 6
# 3
# False

# %% [markdown]
# 6

# %%
A = int(input())
B = int(input())
C = int(input())
result = A < B < C
print(result)
# Out:
# 2
# 77
# 54
# False

# %% [markdown]
# 7

# %%
A = int(input())
B = int(input())
C = int(input())
result = (A < B < C) or (C < B < A)
print(result)
# Out:
# 4
# 2
# 6
# False

# %% [markdown]
# 8

# %%
A = int(input())
B = int(input())
result = (A % 2 != 0) and (B % 2 != 0)
print(result)
# Out:
# 34
# 67
# False

# %% [markdown]
# 9

# %%
A = int(input())
B = int(input())
result = (A % 2 != 0) or (B % 2 != 0)
print(result)
# Out:
# 32
# 54
# False

# %% [markdown]
# 10

# %%
A = int(input())
B = int(input())
result = (A % 2 != 0) ^ (B % 2 != 0)
print(result)

# %% [markdown]
# 11

# %%
A = int(input())
B = int(input())
result = (A % 2) == (B % 2)
print(result)
# Out:
# 67
# 89
# True

# %% [markdown]
# 12

# %%
A = int(input())
B = int(input())
C = int(input())
result = (A > 0) and (B > 0) and (C > 0)
print(result)
# Out:
# 12
# 23
# 65
# True

# %% [markdown]
# 13

# %%
A = int(input())
B = int(input())
C = int(input())
result = (A > 0) or (B > 0) or (C > 0)
print(result)
# Out:
# 23
# 56
# 78
# True

# %% [markdown]
# 14

# %%
A = int(input())
B = int(input())
C = int(input())
result = (int(A > 0) + int(B > 0) + int(C > 0)) == 1
print(result)
# Out:
# 322
# 4489
# 436634
# False

# %% [markdown]
# 15

# %%
A = int(input())
B = int(input())
C = int(input())
result = result = (int(A > 0) + int(B > 0) + int(C > 0)) == 2
print(result)
# Out:
# 3223
# 656
# 654
# False

# %% [markdown]
# 16

# %%
num = int(input())
result = (num % 2 == 0) and (10 <= num <= 99)
print(result)
# Out:
# 6868
# False

# %% [markdown]
# 17

# %%
A = int(input())
is_odd_three_digit = (100 <= A <= 999) and (A % 2 != 0)
print(is_odd_three_digit)
# Out:
# 332
# False

# %% [markdown]
# 18

# %%
A = int(input())
B = int(input())
C = int(input())
has_equal_pair = (A == B) or (B == C) or (A == C)
print(has_equal_pair)
# Out:
# 3434
# 3434
# 556
# True

# %% [markdown]
# 19

# %%
A = int(input())
B = int(input())
C = int(input())
has_opposite_pair = (A == -B) or (B == -C) or (A == -C)
print(f"Высказывание истинно: {has_opposite_pair}")
# Out:
# 3434
# 788
# 54
# Высказывание истинно: False

# %% [markdown]
# 20

# %%
N = int(input())
d1 = N // 100
d2 = (N // 10) % 10
d3 = N % 10
all_unique = (d1 != d2) and (d2 != d3) and (d1 != d3)
print(f"Высказывание истинно: {all_unique}")
# Out:
# 4545
# Высказывание истинно: True

# %% [markdown]
# 21

# %%
N = int(input())
d1 = N // 100
d2 = (N // 10) % 10
d3 = N % 10
is_increasing = (d1 < d2 < d3)
print(f"Высказывание истинно: {is_increasing}")
# Out:
# 5454
# Высказывание истинно: False

# %% [markdown]
# 22

# %%
N = int(input())
d1 = N // 100
d2 = (N // 10) % 10
d3 = N % 10
is_monotonic = (d1 < d2 < d3) or (d1 > d2 > d3)
print(f"Высказывание истинно: {is_monotonic}")
# Out:
# Введите трехзначное число N: 6767
# Высказывание истинно: False
